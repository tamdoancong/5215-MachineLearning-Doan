# %% [markdown]
# <a href="https://colab.research.google.com/github/tamdoancong/5215-MachineLearning-Doan/blob/master/TamDoan_1subject3example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O data.zip https://drive.google.com/u/0/uc?id=1DEMhy3x7ws8Eyv0VGzJNFeYkuXhFDXhC&export=download
# !unzip -o data.zip
# Out:
# --2020-09-25 00:51:26--  https://drive.google.com/u/0/uc?id=1DEMhy3x7ws8Eyv0VGzJNFeYkuXhFDXhC
# Resolving drive.google.com (drive.google.com)... 64.233.189.101, 64.233.189.100, 64.233.189.102, ...
# Connecting to drive.google.com (drive.google.com)|64.233.189.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/skaskgadcr1paqd53ch3bqrbbndck0po/1600995075000/04063593624032689852/*/1DEMhy3x7ws8Eyv0VGzJNFeYkuXhFDXhC [following]
# ...
# --2020-09-25 00:51:27--  https://doc-00-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/skaskgadcr1paqd53ch3bqrbbndck0po/1600995075000/04063593624032689852/*/1DEMhy3x7ws8Eyv0VGzJNFeYkuXhFDXhC
# Resolving doc-00-4g-docs.googleusercontent.com (doc-00-4g-docs.googleusercontent.com)... 64.233.189.132, 2404:6800:4008:c07::84
# ...

# %%
#import the libraries
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %% [markdown]
# 6/ Performance on 3 Example per Subject Datasets,
#
# ---
#
#
#
# ---

# %% [markdown]
# 6.1get 3 random example  for each subject (three examples)

# %%
# load the subject_split datasets
training_subject=pd.read_csv("./data/subject_split/train.csv")
training_subject
# Out:
#       subject#  age  sex  test_time  ...     HNR     RPDE      DFA      PPE
# 0           29   78    0     43.390  ...  24.885  0.38029  0.62114  0.18399
# 1           23   59    1     23.449  ...  21.013  0.45259  0.72558  0.14219
# 2            5   75    0     84.392  ...  22.085  0.56362  0.59660  0.18287
# 3           19   55    0    103.850  ...  22.663  0.63037  0.69406  0.26387
# 4           38   67    0    140.880  ...  21.436  0.55022  0.57203  0.26542
# ...        ...  ...  ...        ...  ...     ...      ...      ...      ...
# 2800         5   75    0     42.406  ...  20.865  0.52891  0.62243  0.20829
# 2801        38   67    0     42.896  ...  20.162  0.57128  0.62273  0.26681
# 2802        21   73    0    123.830  ...  22.404  0.44357  0.62159  0.16353
# 2803         7   72    0    119.300  ...  21.462  0.57086  0.56998  0.23169
# 2804        25   76    0     13.401  ...  19.554  0.60654  0.63592  0.19203
#
# [2805 rows x 22 columns]

# %%
training_subject.shape
# Out:
# (2805, 22)

# %%
n_columns=len(training_subject.columns)

index = training_subject.index
n_rows = len(index)

# %%
#training_subject.count()

# %%
#training_subject['subject#'].count()

# %%
#groupby('subject#').size() count number examples of each subject
#training_subject.groupby('subject#').size()

# %%
#training_subject['subject#'].max()

# %%
 #training_subject[training_subject['subject#']==2].sample(3)

# %%
#x = [4,5,6,7,4,7,8]
#y = set(x)
#for r in y:
# print(r)

# %%
#this cell  code with help of Mica
examples = None

for x in set(training_subject['subject#']):
    
    # print(x)
    e = training_subject[training_subject['subject#']==x].sample(3)
    # print(type(e))
    if examples is None:
      examples = e
    else:
      examples = examples.append(e)
    # break;
      #d=training_subject[training_subject['subject#']==x].sample(3)
      #d=d.append(d)
      #print(x)

#print(examples)
training_subject_ex=examples
#training_subject_ex

# %%
training_subject_ex.shape
# Out:
# (60, 22)

# %%
#1 1 row, .5  will 50% rows
#def training_random_3example_per_subject (m,n):
 # i=1

 # training_subject[training_subject['subject#']==i].sample(n)
 # i+=1
  #training_subject+=training_subject
  #if i=m break
  #return training_subject
#training_random_3example_per_subject (training_subject['subject#'].max(),3)

# %%
#i=2
#while (i <(training_subject['subject#'].max()+1)):
  
#
  #  training_subject[training_subject['subject#']==i].sample(3)
   # i+=1
    #training_subject+=training_subject

# %%
#training_subject.sort_values(by=['subject#'], inplace=True)
#training_subject

# %%
#The index represents the sequence of values on the far left-hand side of the DataFrame. 
#All the values in the index are in bold font. Each individual value of the index is called a label.
# Sometimes the index is referred to as the row labels. In the example above,
# the row labels are not very interesting and are just the integers beginning from 2371  to 1559,
# where n is the number of rows in the table. Pandas defaults DataFrames with this simple index.

#training_subject.index
#training_subject

# %%
 #training_subject.columns
#type(training_subject.index)

# %%
#type(training_subject.columns)

# %%
#type(training_subject.values)

# %%
#group examples (rows in the tables) by subject .groupby(['subject#'], as_index=False) and convert each group to an aggregate ...agg(groupingFunction),
# where groupingFunction is defined in the code to generate a record with the mean and standard deviation of each speech metric,
groupingFunction={
    'age':'first',
    'sex':'first',
    'test_time':'mean',
    'motor_UPDRS':'mean',
    'total_UPDRS':'mean',
    'Jitter(%)':['mean','std'],
    'Jitter(Abs)':['mean','std'],
    'Jitter:RAP':['mean','std'],
    'Jitter:PPQ5':['mean','std'],
    'Jitter:DDP':['mean','std'],
    'Shimmer':['mean','std'],
    'Shimmer(dB)':['mean','std'],
    'Shimmer:APQ3':['mean','std'],
    'Shimmer:APQ5':['mean','std'],
    'Shimmer:APQ11':['mean','std'],
    'Shimmer:DDA':['mean','std'],
    'NHR':['mean','std'],
    'HNR':['mean','std'],
    'RPDE':['mean','std'],
    'DFA':['mean','std'],
    'PPE':['mean','std'],
}
#training_subject_ex=training_subject.groupby(['subject#'], as_index=False).agg(groupingFunction)
#training_subject_ex=training_subject.sample(frac = 1.0).groupby('subject#').head(1)
#training_subject_ex=training_subject.groupby(['subject#'], as_index=False).agg(['min','mean','max'])
#training_subject_ex=training_subject.groupby({'subject#':['min'],'subject#':['median'],'subject#':['max']}#)
#training_subject_ex

# %%
training_subject_ex.shape
# Out:
# (60, 22)

# %%
#copy the clinician’s total_UPDRS score column to subject_ex_targets, 
total_training_subject_ex_targets=training_subject_ex['total_UPDRS']
#total_training_subject_ex_targets

# %%
#copy the clinician’s motor_UPDRS score column to motor_targets
motor_training_subject_ex_targets=training_subject_ex['motor_UPDRS' ]
#motor_training_subject_ex_targets

# %%
#training_subject_ex=training_subject_ex.drop(columns=['total_UPDRS','motor_UPDRS','subject#'])
#training_subject_ex

# %%
training_subject_ex=training_subject_ex.drop(columns=['total_UPDRS','motor_UPDRS','subject#'])

# %%
#initialize a linear_model.LinearRegression() model with its default parameters,
reg = LinearRegression(fit_intercept=True,normalize=False)

# %%
#train model_3.1 using the fit method, 
# training_subject_ex(not include'total_UPDRS','motor_UPDRS' ) and 
#total_training_subject_ex_targets  which extrcact from "./data/subject_split/train.csv" and group by subject and aggreagate mean, std
reg.fit(training_subject_ex,total_training_subject_ex_targets)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#load tuning dataset
tuning_subject=pd.read_csv("./data/subject_split/dev.csv")
tuning_subject
# Out:
#       subject#  age  sex  test_time  ...     HNR     RPDE      DFA       PPE
# 0            6   63    0   124.3400  ...  18.697  0.48090  0.70231  0.243810
# 1            6   63    0   159.3400  ...  21.714  0.52553  0.64583  0.227670
# 2           15   65    0   117.5200  ...  29.605  0.41836  0.53587  0.120140
# 3           18   65    0     4.3625  ...  27.909  0.32235  0.62499  0.117190
# 4           15   65    0   166.6600  ...  31.096  0.42936  0.55502  0.077124
# ...        ...  ...  ...        ...  ...     ...      ...      ...       ...
# 1092         6   63    0   117.3300  ...  23.526  0.39939  0.64157  0.158100
# 1093        11   55    0    49.4560  ...  23.929  0.47948  0.67020  0.170330
# 1094        15   65    0   194.5500  ...  28.281  0.41086  0.54318  0.092377
# 1095        33   66    1    79.4440  ...  15.060  0.49334  0.56824  0.320830
# 1096        20   67    0    67.8880  ...  22.226  0.42277  0.80078  0.245550
#
# [1097 rows x 22 columns]

# %%
texamples = None

for x in set(tuning_subject['subject#']):
    
    # print(x)
    e = tuning_subject[tuning_subject['subject#']==x].sample(3)
    
    texamples = examples.append(e)
tuning_subject_ex=examples
tuning_subject_ex
# Out:
#       subject#  age  sex  test_time  ...     HNR     RPDE      DFA       PPE
# 1318         2   58    0    80.7510  ...  18.761  0.55014  0.77786  0.237630
# 1927         2   58    0    68.7290  ...  15.777  0.56732  0.74010  0.231560
# 1004         2   58    0    38.7150  ...  20.660  0.44549  0.73798  0.176840
# 1150        35   71    0    34.4230  ...  20.878  0.41602  0.72302  0.273080
# 2278        35   71    0    27.4440  ...  18.505  0.49754  0.75031  0.251940
# 1915        35   71    0    48.8880  ...  23.778  0.45499  0.70735  0.215980
# 1810         4   74    0    72.6830  ...  20.999  0.65380  0.65895  0.160510
# 7            4   74    0    30.7240  ...  20.802  0.62754  0.61237  0.142950
# 1431         4   74    0   156.7100  ...  19.742  0.61046  0.62946  0.213070
# 2286         5   75    0    58.5610  ...  18.138  0.57407  0.67395  0.274770
# 276          5   75    0   119.3800  ...  20.153  0.65375  0.59971  0.258250
# ...

# %%
tuning_subject_ex.shape
# Out:
# (60, 22)

# %%
#copy the clinician’s total_UPDRS score column to total_tuning_subject_ex_targets, 
total_tuning_subject_ex_targets=tuning_subject_ex['total_UPDRS']
#total_tuning_subject_ex_targets

# %%
#copy the clinician’s motor_UPDRS score column to motor_tuning_subject_ex_targets
motor_tuning_subject_ex_targets=tuning_subject_ex['motor_UPDRS' ]
#motor_tuning_subject_ex_targets

# %%
#drop the total_UPDRS, motor_UPDRS and subject# columns
tuning_subject_ex=tuning_subject_ex.drop(columns=['total_UPDRS','motor_UPDRS','subject#'])
#tuning_subject_ex

# %%
tuning_subject_ex.shape
# Out:
# (60, 19)

# %%
total_tuning_subject_ex_targets
# Out:
# 1318    14.816
# 1927    14.694
# 1004    14.391
# 1150    54.391
# 2278    54.312
# 1915    54.556
# 1810    23.480
# 7       18.008
# 1431    27.454
# 2286    40.910
# 276     42.989
# 1620    42.232
# 294     23.982
# 1372    25.424
# 2299    26.743
# 2576    22.593
# 2057    24.963
# 133     24.108
# 812     36.903
# 1839    37.920
# 2277    39.947
# 1841    41.241
# 1767    40.627
# 1554    36.930
# 2588    29.835
# 1800    29.836
# 1790    30.437
# 2082    23.122
# 2036    21.008
# 455     23.269
# 2394    25.704
# 1116    25.358
# 757     25.939
# 760     34.807
# 2512    39.738
# 691     32.379
# 1051    26.375
# 295     24.678
# 112     26.103
# 769     40.224
# 2256    39.481
# 490     39.423
# 1320    26.274
# 1939    27.607
# 914     23.134
# 2674    53.960
# 807     53.960
# 388     46.997
# 185     35.223
# 1895    29.205
# 630     38.350
# 648     28.425
# 2490    28.032
# 2639    28.032
# 2504    33.523
# 544     29.476
# 2645    36.134
# 2716    24.084
# ...

# %%
training_subject_ex.shape
# Out:
# (60, 19)

# %%
#evaluate model_3.2 using score 
#The coefficient R^2 is defined as (1 - u/v), where u is the regression sum of squares ((y_true - y_pred) ** 2).sum() and 
#v is the residual sum of squares ((y_true - y_true.mean()) ** 2).sum(). Best possible score is 1.0 
#and it can be negative (because the model can be arbitrarily worse). A constant model that always predicts the expected value of y,
# disregarding the input features, would get a R^2 score of 0.0.

#tuning_subject and tuning_targets_subject are extracted from "./data/subject_split/dev.csv" 
#grouby subject and aggregate (not include'total_UPDRS','motor_UPDRS', 'subject number' )
reg.score(tuning_subject_ex, total_tuning_subject_ex_targets)
# Out:
# 0.2985889802989514

# %%
#to get the output for  prediction_target_subject_x,tuning_subject_ex is not include'total_UPDRS','motor_UPDRS''subject# 
prediction_target_subject_ex=reg.predict(tuning_subject_ex)

# %%
from sklearn.metrics import mean_squared_error

# %%
#mean_squared_error of model_3.1 :tuning_subject_ex and tuning_targets_subject_ex are extracted from "./data/subject_split/dev.csv" 
#grouby subject and aggregate
#tuning_subject_ex does not include'total_UPDRS','motor_UPDRS''subject' 
mse_model_3_1 =mean_squared_error(total_tuning_subject_ex_targets,prediction_target_subject_ex)
mse_model_3_1
# Out:
# 70.27649287241417

# %%
#root mean_squared_error model_3.1 tuning_subject and tuning_targets_subject are extracted from "./data/subject_split/dev.csv" 
#(not include'total_UPDRS','motor_UPDRS''age','sex','test_time' )
np.sqrt(mse_model_3_1 )
# Out:
# 8.383107590411456

# %%
reg.coef_
# Out:
# array([ 4.95125391e-01, -2.40188098e+00,  7.53750327e-05, -1.22340556e+04,
#         4.39902173e+05,  5.88726395e+05,  5.80332132e+03, -1.92540355e+05,
#         3.75295679e+02, -1.06664120e+01,  1.05620534e+05, -7.99696207e+02,
#         2.14973405e+02, -3.52081640e+04,  8.29308688e+01,  1.78418432e+00,
#        -1.52529717e+01, -6.23227776e+00,  5.79375214e+01])

# %%
reg.coef_
# Out:
# array([ 4.95125391e-01, -2.40188098e+00,  7.53750327e-05, -1.22340556e+04,
#         4.39902173e+05,  5.88726395e+05,  5.80332132e+03, -1.92540355e+05,
#         3.75295679e+02, -1.06664120e+01,  1.05620534e+05, -7.99696207e+02,
#         2.14973405e+02, -3.52081640e+04,  8.29308688e+01,  1.78418432e+00,
#        -1.52529717e+01, -6.23227776e+00,  5.79375214e+01])

# %% [markdown]
# Review
# Hyper-parameter Tuning: This Linear Regression model only has one meaningful hyperparameter: **normalize = True**; the default value is false. Feel free to modify this value and rerun your best model to see if you get any better performance. We will explore hyperparameter tuning in a future module.

# %%
#initialize a linear_model.LinearRegression() model with its default parameters,
reg = LinearRegression(fit_intercept=True,normalize=True)

# %%
reg.fit(training_subject_ex,total_training_subject_ex_targets)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
reg.score(tuning_subject_ex, total_tuning_subject_ex_targets)
# Out:
# 0.2985889802989423

# %%
prediction_target_subject_ex=reg.predict(tuning_subject_ex)

# %%
mse_model_3_1 =mean_squared_error(total_tuning_subject_ex_targets,prediction_target_subject_ex)
mse_model_3_1
# Out:
# 70.27649287241508

# %%
np.sqrt(mse_model_3_1 )
# Out:
# 8.38310759041151
